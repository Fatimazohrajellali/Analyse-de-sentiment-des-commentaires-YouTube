# %%
import googleapiclient.discovery
import csv
from google.colab import drive

# Monte Google Drive
drive.mount('/content/drive')

# Clé API YouTube
API_KEY = "TON_CLE_API"

# IDs des vidéos
VIDEO_IDS = ["J1Z1A46FknM", "ggAgLZ9CMU4", "-JnXUD0XxMA", "UKQcJUj8Bjs", "O4ZEKE5p7so", "Vdt8Og5mY0w"]

# Initialisation de l'API YouTube
youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=API_KEY)

def get_video_title(video_id):
    request = youtube.videos().list(part="snippet", id=video_id)
    response = request.execute()
    return response["items"][0]["snippet"]["title"] if response["items"] else "Titre inconnu"

def get_comments(video_id):
    comments = []
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100
    )
    response = request.execute()

    for item in response.get("items", []):
        comment = item["snippet"]["topLevelComment"]["snippet"]
        comments.append(comment["textDisplay"])

    return comments

# Chemin du fichier CSV sur Google Drive
csv_file_path = "/content/drive/My Drive/youtube_comments.csv"

# Écriture des données dans un fichier CSV
with open(csv_file_path, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Video ID", "Video Title", "Comment"])

    for video_id in VIDEO_IDS:
        title = get_video_title(video_id)
        comments = get_comments(video_id)
        for comment in comments:
            writer.writerow([video_id, title, comment])

print(f"Les commentaires ont été enregistrés dans {csv_file_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Les commentaires ont été enregistrés dans /content/drive/My Drive/youtube_comments.csv

# %%
import pandas as pd

# Charger le fichier CSV
df = pd.read_csv("/content/drive/My Drive/youtube_comments.csv")  # Remplace par le chemin exact de ton fichier

# Afficher des informations sur le fichier
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Video ID     600 non-null    object
#  1   Video Title  600 non-null    object
#  2   Comment      600 non-null    object
# dtypes: object(3)
# memory usage: 14.2+ KB

# %%
df
# Out:
#         Video ID                              Video Title  \
# 0    J1Z1A46FknM  QUI EST L'IMPOSTEUR ? (ft Eric & Ramzy)
# 1    J1Z1A46FknM  QUI EST L'IMPOSTEUR ? (ft Eric & Ramzy)
# 2    J1Z1A46FknM  QUI EST L'IMPOSTEUR ? (ft Eric & Ramzy)
# 3    J1Z1A46FknM  QUI EST L'IMPOSTEUR ? (ft Eric & Ramzy)
# 4    J1Z1A46FknM  QUI EST L'IMPOSTEUR ? (ft Eric & Ramzy)
# ..           ...                                      ...
# 595  Vdt8Og5mY0w    L'INVENTION DU CORPS HUMAIN - CYPRIEN
# 596  Vdt8Og5mY0w    L'INVENTION DU CORPS HUMAIN - CYPRIEN
# 597  Vdt8Og5mY0w    L'INVENTION DU CORPS HUMAIN - CYPRIEN
# 598  Vdt8Og5mY0w    L'INVENTION DU CORPS HUMAIN - CYPRIEN
# 599  Vdt8Og5mY0w    L'INVENTION DU CORPS HUMAIN - CYPRIEN
#
#                                                Comment
# 0    Mais Eric et Ramzy, quand ils partent dans leu...
# 1    La meilleure vidéo de squezzy <a href="https:/...
# 2    A <a href="https://www.youtube.com/watch?v=J1Z...
# ...

# %%
import googleapiclient.discovery
import csv
from google.colab import drive

# Monte Google Drive
drive.mount('/content/drive')

# Clé API YouTube
API_KEY = "TON_CLE_API"

# IDs des vidéos
VIDEO_IDS = ["J1Z1A46FknM", "ggAgLZ9CMU4", "-JnXUD0XxMA", "UKQcJUj8Bjs", "O4ZEKE5p7so", "Vdt8Og5mY0w"]

# Initialisation de l'API YouTube
youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=API_KEY)

def get_video_title(video_id):
    request = youtube.videos().list(part="snippet", id=video_id)
    response = request.execute()
    return response["items"][0]["snippet"]["title"] if response["items"] else "Titre inconnu"

def get_all_comments(video_id):
    comments = []
    next_page_token = None

    while True:
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100,
            pageToken=next_page_token
        )
        response = request.execute()

        for item in response.get("items", []):
            comment = item["snippet"]["topLevelComment"]["snippet"]
            comments.append(comment["textDisplay"])

        next_page_token = response.get("nextPageToken")
        if not next_page_token:
            break

    return comments

# Chemin du fichier CSV sur Google Drive
csv_file_path = "/content/drive/My Drive/youtube_comments1.csv"

# Écriture des données dans un fichier CSV
with open(csv_file_path, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Video ID", "Video Title", "Comment"])

    for video_id in VIDEO_IDS:
        title = get_video_title(video_id)
        comments = get_all_comments(video_id)
        for comment in comments:
            writer.writerow([video_id, title, comment])

print(f"Les commentaires ont été enregistrés dans {csv_file_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Les commentaires ont été enregistrés dans /content/drive/My Drive/youtube_comments1.csv

# %%
import pandas as pd

# Charger le fichier CSV
df = pd.read_csv("/content/drive/My Drive/youtube_comments1.csv")  # Remplace par le chemin exact de ton fichier

# Afficher des informations sur le fichier
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96151 entries, 0 to 96150
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Video ID     96151 non-null  object
#  1   Video Title  96151 non-null  object
#  2   Comment      96151 non-null  object
# dtypes: object(3)
# memory usage: 2.2+ MB

# %%
import googleapiclient.discovery
import csv
from google.colab import drive

# Monte Google Drive
drive.mount('/content/drive')

# Clé API YouTube
API_KEY = "TON_CLE_API"

# IDs des vidéos
VIDEO_IDS = ["J1Z1A46FknM", "ggAgLZ9CMU4", "-JnXUD0XxMA", "UKQcJUj8Bjs", "O4ZEKE5p7so", "Vdt8Og5mY0w"]

# Initialisation de l'API YouTube
youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=API_KEY)

def get_video_title(video_id):
    request = youtube.videos().list(part="snippet", id=video_id)
    response = request.execute()
    return response["items"][0]["snippet"]["title"] if response["items"] else "Titre inconnu"

def get_limited_comments(video_id, max_comments=20000):
    comments = []
    next_page_token = None

    while len(comments) < max_comments:
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100,
            pageToken=next_page_token
        )
        response = request.execute()

        for item in response.get("items", []):
            if len(comments) >= max_comments:
                break
            comment = item["snippet"]["topLevelComment"]["snippet"]
            comments.append(comment["textDisplay"])

        next_page_token = response.get("nextPageToken")
        if not next_page_token:
            break

    return comments

# Chemin du fichier CSV sur Google Drive
csv_file_path = "/content/drive/My Drive/youtube_comments2.csv"

# Écriture des données dans un fichier CSV
with open(csv_file_path, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Video ID", "Video Title", "Comment"])

    total_comments = 0
    for video_id in VIDEO_IDS:
        if total_comments >= 20000:
            break
        title = get_video_title(video_id)
        comments = get_limited_comments(video_id, max_comments=20000 - total_comments)
        for comment in comments:
            writer.writerow([video_id, title, comment])
            total_comments += 1
            if total_comments >= 20000:
                break

print(f"Les commentaires ont été enregistrés dans {csv_file_path} (limité à 20 000 commentaires)")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Les commentaires ont été enregistrés dans /content/drive/My Drive/youtube_comments2.csv (limité à 20 000 commentaires)

# %%
import pandas as pd

# Charger le fichier CSV
df = pd.read_csv("/content/drive/My Drive/youtube_comments2.csv")  # Remplace par le chemin exact de ton fichier

# Afficher des informations sur le fichier
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Video ID     20000 non-null  object
#  1   Video Title  20000 non-null  object
#  2   Comment      20000 non-null  object
# dtypes: object(3)
# memory usage: 468.9+ KB
